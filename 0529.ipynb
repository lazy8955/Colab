# %% [markdown]
# <a href="https://colab.research.google.com/github/lazy8955/Colab/blob/main/0529.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('popular')
nltk.download('all-corpora')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# ...

# %%
ls '/content/drive/MyDrive/123'
# Out:
# 1.txt  2.txt  3.txt

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader

#PlaintextCorpusReader
#讀取純文字檔案，並把它們當作語料庫（corpus）來分析
corpus_root = '/content/drive/MyDrive/123' # 請改成自己的路徑 File Path
wordlists = PlaintextCorpusReader(corpus_root, '.*') # .* => find all files, .txt => only find txt files

books = wordlists.fileids() # 回傳檔名
print(books)
# Out:
# ['1.txt', '2.txt', '3.txt']

# %%
import nltk
testText = wordlists.words('3.txt')
print(testText)

# 轉換成 NLTK 的 Text 類別物件，為了能夠進行分析
single = nltk.text.Text(testText)
print(single)
# Out:
# ['Fox', 'and', 'cat', 'are', 'walking', 'in', 'the', ...]
# <Text: Fox and cat are walking in the woods...>

# %%
# 文章中字詞出現次數
single.count("Fox")
# Out:
# 9

# %%
# 搜尋字詞功能
single.concordance("Fox", lines=100)  # 查找 'happy' 出現的上下文
# Out:
# Displaying 9 of 9 matches:
#                                       Fox and cat are walking in the woods . Th
# ' t like dogs . Dogs will kill them . Fox stops . " Can you hear some dogs ?" H
# t ' s go ." " I am not afraid ," says Fox . Laughing . " The dogs cannot get me
#  I have 100 plans to run away ," says Fox . " I know only one ," says Cat . Fox
# Fox . " I know only one ," says Cat . Fox laughs . " Ha ha ha ! They will kill
# plan ," she says ." What ' s yours ?" Fox is thinking . Fox has many ideas . "
# " What ' s yours ?" Fox is thinking . Fox has many ideas . " Do I do this ?" he
# that ? Oh no !" The dogs are coming . Fox is afraid . He cannot think . Fox run
# g . Fox is afraid . He cannot think . Fox runs away as fast as he can . He is n

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# doc: https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

#讀取文本
file_text = open('/content/drive/MyDrive/123/1.txt','r').read()


# background_color 背景顏色
# width 寬
# height 高
# margin 圖片邊緣
# max_font_size 設定文字中最大的大小是多少
# min_font_size
# max_words  文字雲顯示最大詞數
# font_path="/tmp/DFFT_C7.ttc", #設置字體

temp = WordCloud(
    background_color="white",
    width=2000,
    height=1000,
    margin= 10,
).generate(file_text)


plt.imshow(temp)
plt.axis("off")
plt.show()


# 練習

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {"it's", "mustn't", 'ours', "why's", 'more', 'some', 'cannot', "you've", "he'll", 'having', 'which', "wouldn't", 'myself', 'an', "we'd", 'it', 'has', "where's", 'no', 'ourselves', "shan't", 'can', 'does', 'ever', 'few', 'before', "let's", "she'll", 'is', "hasn't", 'down', "when's", 'below', 'else', 'between', "didn't", 'her', "i'd", "we've", "i'm", "hadn't", "they'd", 'yourself', 'very', 'should', 'that', 'also', 'our', 'any', "shouldn't", 'just', 'once', 'com', "isn't", 'am', "you're", "she'd", "haven't", 'i', 'all', "what's", 'my', 'itself', 'were', "we'll", "he's", 'as', "can't", 'hence', 'are', 'against', "they've", 'yourselves', 'these', 'his', 'each', 'shall', "you'd", "weren't", 'was', 'doing', 'when', 'being', 'k', 'whom', 'other', 'however', 'why', 'get', 'themselves', 'over', 'those', 'for', 'into', 'but', 'me', 'too', "i've", 'did', 'about', 'like', "we're", "who's", 'than', 'hers', 'do', 'have', "wasn't", 'their', "aren't", 'could', 'of', 'while', 'we', 'during', 'and', '
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/123/1.txt','r').read()
# The following import and file read are duplicates and can be removed
# from wordcloud import WordCloud, STOPWORDS
# import matplotlib.pyplot as plt
# f = open('/content/drive/MyDrive/123/1.txt','r').read()

# stopwords 停用字詞
stop = ["it's", "mustn't", 'ours', "why's", "more", "some"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white", ##fff
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#練習濾掉stopword及指定字詞
# The following lines are causing the IndentationError and should be removed
#     background_color="white", ##fff
#     width=1500,
#     height=1000,
#     margin=2,
#     stopwords=stop
# ).generate(f)


# plt.imshow(wordcloud)
# plt.axis("off")
# plt.show()

#練習濾掉stopword及指定字詞

# %%
findList = ["it's", "mustn't", 'ours', "why's", "more", "some" ]

for fileid in books:
   myWords = wordlists.words(fileid)
   myText = nltk.text.Text(myWords)
   print(fileid)
   myText.dispersion_plot(findList)
# Out:
# 1.txt
# 2.txt
# 3.txt

# %%
cfd = nltk.ConditionalFreqDist(
           (target, fileid[:7]) # 表格下方顯示txt檔名前七個字
           for fileid in wordlists.fileids()
           for w in wordlists.words(fileid)
           #List裡面請改成你要搜尋的字詞
           for target in ["it's", "mustn't", 'ours', "why's", "more", "some" ]
           if w.lower().startswith(target))
cfd.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import matplotlib.pyplot as plt

x = ["ours", "why's", "more", "some" ]
y = [20, 15, 26, 10]


plt.bar(x, y)     #繪製長條圖
plt.title('Key words')          #設定圖形標題
plt.xlabel('Words')                #設定X軸標籤
plt.ylabel('Nums')                   #設定Y軸標籤
plt.figure(figsize=(5,4))
plt.show()

plt.bar(x, y)     #繪製長條圖
plt.title('Key words')          #設定圖形標題
plt.xlabel('Words')                #設定X軸標籤
plt.ylabel('Nums')                   #設定Y軸標籤
plt.figure(figsize=(5,4))
plt.show()
